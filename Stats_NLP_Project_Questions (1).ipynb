# %% [markdown]
# # Predict tags on StackOverflow with linear models

# %% [markdown]
# In this assignment you will learn how to predict tags for posts from [StackOverflow](https://stackoverflow.com). To solve this task you will use multilabel classification approach.
#
# ### Libraries
#
# In this task you will need the following libraries:
# - [Numpy](http://www.numpy.org) — a package for scientific computing.
# - [Pandas](https://pandas.pydata.org) — a library providing high-performance, easy-to-use data structures and data analysis tools for the Python
# - [scikit-learn](http://scikit-learn.org/stable/index.html) — a tool for data mining and data analysis.
# - [NLTK](http://www.nltk.org) — a platform to work with natural language.

# %% [markdown]
# ### Data
#
# You can find all data required for this assignment into the folder `/data`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Text preprocessing

# %% [markdown]
# For this assignment you will need to use a list of stop words. It can be downloaded from *nltk*:

# %%
import sklearn
import ast

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# In this task you will deal with a dataset of post titles from StackOverflow. You are provided a split to 3 sets: *train*, *validation* and *test*. All corpora (except for *test*) contain titles of the posts and corresponding tags (100 tags are available). The *test* set doesn't contain answers. Upload the corpora using *pandas* and look at the data:

# %%
from ast import literal_eval
import pandas as pd
import numpy as np

# %% [markdown]
# Literal_eval package takes care of the preprocessing for the string so that it can be used in python. To know more on literal_eval please see the below documentation <br>
# https://kite.com/python/docs/ast.literal_eval

# %% [markdown]
# ## Task 1: Create training, testing and validation data from the files given. Use title to be the independent variable and tags to be the dependent variable ( 5 points)

# %% [markdown]
# Note: Ensure you apply literal_eval function on the tags column to ensure all the tags are readable in python

# %%
train_df = pd.read_csv('/content/drive/My Drive/NLP/Statistical NLP/train.tsv', sep='\t')

# %%
validation_df = pd.read_csv('/content/drive/My Drive/NLP/Statistical NLP/validation.tsv', sep='\t')

# %%
test_df = pd.read_csv('/content/drive/My Drive/NLP/Statistical NLP/test.tsv', sep='\t')

# %%
train_df.head()
# Out:
#                                                title                      tags
# 0                How to draw a stacked dotplot in R?                     ['r']
# 1  mysql select all records where a datetime fiel...          ['php', 'mysql']
# 2             How to terminate windows phone 8.1 app                    ['c#']
# 3  get current time in a specific country via jquery  ['javascript', 'jquery']
# 4                      Configuring Tomcat to Use SSL                  ['java']

# %%
x_train = train_df['title']
y_train = train_df['tags'].apply(literal_eval)

# %%
y_train[1]
# Out:
# ['php', 'mysql']

# %%
validation_df.head()
# Out:
#                                                title                               tags
# 0                         Why odbc_exec always fail?                     ['php', 'sql']
# 1  Access a base classes variable from within a c...                     ['javascript']
# 2  Content-Type "application/json" not required i...          ['ruby-on-rails', 'ruby']
# 3         Sessions in Sinatra: Used to Pass Variable                ['ruby', 'session']
# 4  Getting error - type "json" does not exist - i...  ['ruby-on-rails', 'ruby', 'json']

# %%
x_val = validation_df['title']
y_val = validation_df['tags'].apply(literal_eval)

# %%
test_df.head()
# Out:
#                                                title
# 0  Warning: mysql_query() expects parameter 2 to ...
# 1  get click coordinates from <input type='image'...
# 2  How to implement cloud storage for media asset...
# 3  What is catcomplete in jQuery's autocomplete p...
# 4    Error building Android app with Cordova 3.1 CLI

# %%
x_test = test_df['title']
y_test = []

# %% [markdown]
# ## Task 2 (Pre-processing). Implement the function *text_prepare* following the instructions. After that, run the function *test_text_prepare* to test it on tiny cases. (10 points)
#
# One of the most known difficulties when working with natural data is that it's unstructured. For example, if you use it "as is" and extract tokens just by splitting the titles by whitespaces, you will see that there are many "weird" tokens like *3.5*, *?*,  *{}*, etc. To prevent the problems, it's usually useful to prepare the data in a custom way

# %%
import re

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def text_prepare(text): ### The function will take in text and lower case it remove the stopwords, symbols and return it
    
    #import pdb; pdb.set_trace()
    text = text.lower()                          ### Write a code which can change the input text to lowercase
    text = REPLACE_BY_SPACE_RE.sub(' ', text)    ### Write a code which replaces REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text)          ### Write a code which deletes symbols which are in BAD_SYMBOLS_RE from text
    pattern = re.compile(r'\b(' + r'|'.join(STOPWORDS) + r')\b\s*') 
    text = pattern.sub('', text)                 ### Write a code which deletes stopwords from text
    text = re.sub(' +', ' ', text)
        
    return text

# %%
def test_text_prepare():
    import pdb; 
    examples = ["SQL Server - any equivalent of Excel's CHOOSE function?",
                "How to free c++ memory vector<int> * arr?"]
    answers = ["sql server equivalent excels choose function", 
               "free c++ memory vectorint arr"]
    for ex, ans in zip(examples, answers):
        #pdb.set_trace()
        if text_prepare(ex) != ans:
            return "Wrong answer for the case: '%s'" % ex
    return 'Basic tests are passed.'

# %% [markdown]
# Execute the test_text_prepare function

# %%
test_text_prepare()
# Out:
# 'Basic tests are passed.'

# %% [markdown]
# *Note: You should pass the above test to ensure the text preprocessing is done before our analysis*

# %% [markdown]
# Now we can preprocess the titles using function *text_prepare* and  making sure that the headers don't have bad symbols:

# %%
x_train = [text_prepare(x) for x in x_train]
x_val = [text_prepare(x) for x in x_val]
x_test = [text_prepare(x) for x in x_test]

# %% [markdown]
# Print the top 5 elements in x_train

# %%
x_train[:5]
# Out:
# ['draw stacked dotplot r',
#  'mysql select records datetime field less specified value',
#  'terminate windows phone 81 app',
#  'get current time specific country via jquery',
#  'configuring tomcat use ssl']

# %% [markdown]
# ## Task 2 (WordsTagsCount) - Find 3 most popular tags and 3 most popular words in the train data. - 5 points

# %% [markdown]
# Note: The words which appear the most are considered as popular in this case!

# %%
import collections 
from collections import Counter

words=[]
tag_w=[]
for i in range(0,100000):
    
    words = words+(re.findall(r'\w+', x_train[i])) # words cantain all the words in the dataset
                                                   # \w this searches for groups that have alphanumerics
    tag_w=tag_w+y_train[i]                         # tag_w contain all tags that are present in train dataset

words_counts = Counter(words) # counter create the dictinary of unique words with their frequncy
tags_counts=Counter(tag_w)

# %%
most_common_tags = sorted(tags_counts.items(), key=lambda x: x[1], reverse=True)[:3]
most_common_words = sorted(words_counts.items(), key=lambda x: x[1], reverse=True)[:3]

# %% [markdown]
# We are assuming that *tags_counts* and *words_counts* are dictionaries like `{'some_word_or_tag': frequency}`. After applying the sorting procedure, results will be look like this: `[('most_popular_word_or_tag', frequency), ('less_popular_word_or_tag', frequency), ...]`.
#
# eg:
# Tag 1 - 100 Tag 2 - 65 Tag 3 - 250 <br>
# after sorting looks like, <br>
# Tag 3 - 250 Tag 1 - 100 Tag 2 - 65

# %%
print(most_common_words)
print(most_common_tags)
# Out:
# [('using', 8279), ('c', 8183), ('php', 5624)]
# [('javascript', 19078), ('c#', 19077), ('java', 18661)]

# %%
most_common_words[2][0]
# Out:
# 'php'

# %%
most_common_words[2][1]
# Out:
# 5624

# %% [markdown]
# ## Task - 3 Transforming text to a vector (10 points)
#
# Machine Learning algorithms work with numeric data and we cannot use the provided text data "as is". There are many ways to transform text data to numeric vectors. In this task you will try to use two of them.
#
# #### Bag of words
#
# One of the well-known approaches is a *bag-of-words* representation. To create this transformation, follow the steps:
# 1. Find *N* most popular words in train corpus and numerate them. Now we have a dictionary of the most popular words.
# 2. For each title in the corpora create a zero vector with the dimension equals to *N*.
# 3. For each text in the corpora iterate over words which are in the dictionary and increase by 1 the corresponding coordinate.
#
# Let's try to do it for a toy example. Imagine that we have *N* = 4 and the list of the most popular words is
#
#     ['hi', 'you', 'me', 'are']
#
# Then we need to numerate them, for example, like this:
#
#     {'hi': 0, 'you': 1, 'me': 2, 'are': 3}
#
# And we have the text, which we want to transform to the vector:
#
#     'hi how are you'
#
# For this text we create a corresponding zero vector
#
#     [0, 0, 0, 0]
#
# And iterate over all words, and if the word is in the dictionary, we increase the value of the corresponding position in the vector:
#
#     'hi':  [1, 0, 0, 0]
#     'how': [1, 0, 0, 0] # word 'how' is not in our dictionary
#     'are': [1, 0, 0, 1]
#     'you': [1, 1, 0, 1]
#
# The resulting vector will be
#
#     [1, 1, 0, 1]
#
# Implement the described encoding in the function *my_bag_of_words* with the size of the dictionary equals to 5000. To find the most common words use train data. You can test your code using the function *test_my_bag_of_words*.

# %%
DICT_SIZE = 5000
#most_common_words contain 5000 words in sorted order of frequncy
most_common_words = sorted(words_counts.items(), key=lambda x: x[1], reverse=True)[:5000] 
WORDS_TO_INDEX = {}
INDEX_TO_WORDS = {}

for i in range(0,5000):
    WORDS_TO_INDEX[most_common_words[i][0]]=i # most_common_words[i][0] means extracting ith word from the dictionary, 
                                              # words to index contains the index value of the word
    INDEX_TO_WORDS[i]=most_common_words[i][0] # index to word contains the word corresponding to the index

ALL_WORDS = WORDS_TO_INDEX.keys()

def my_bag_of_words(text, words_to_index, dict_size):
        
    result_vector = np.zeros(dict_size)
    y=text.split(" ")
    for i in range(0,len(y)):
        for key,value in words_to_index.items():
            if y[i]==key:
                result_vector[words_to_index[key]]=result_vector[words_to_index[key]]+1  

    return result_vector

# %%
def test_my_bag_of_words():
    words_to_index = {'hi': 0, 'you': 1, 'me': 2, 'are': 3}
    examples = ['hi how are you']
    answers = [[1, 1, 0, 1]]
    for ex, ans in zip(examples, answers):
        if (my_bag_of_words(ex, words_to_index, 4) != ans).any():
            return "Wrong answer for the case: '%s'" % ex
    return 'Basic tests are passed.'

# %% [markdown]
# Execute the test_text_prepare function <br>
# *<u>Note:</u> You should pass the above test to ensure BOW is working correctly!*

# %%
test_my_bag_of_words()
# Out:
# 'Basic tests are passed.'

# %% [markdown]
# Now apply the implemented function to all samples (this might take up to a minute):

# %%
from scipy import sparse as sp_sparse

# %%
x_train_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(my_bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in x_train])
x_val_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(my_bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in x_val])
x_test_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(my_bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in x_test])
print('x_train shape ', x_train_mybag.shape)
print('x_val shape ', x_val_mybag.shape)
print('x_test shape ', x_test_mybag.shape)
# Out:
# x_train shape  (100000, 5000)
# x_val shape  (30000, 5000)
# x_test shape  (20000, 5000)

# %% [markdown]
# As you might notice, we transform the data to sparse representation, to store the useful information efficiently. There are many types: of such representations, however sklearn algorithms can work only with  csr matrix, so we will use this one.<br>
# <u>Documentations on sparse matrix:</u> <br>
# (https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.csr_matrix.html#scipy.sparse.csr_matrix)
# (https://docs.scipy.org/doc/scipy/reference/sparse.html)

# %% [markdown]
# For the 11th row in *X_train_mybag* find how many non-zero elements it has. In this task the answer (variable *non_zero_elements_count*) should be a number, e.g. 20.

# %%
x_train_mybag[11].toarray()[0]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
row = x_train_mybag[11].toarray()[0]
non_zero_elements_count=0
for i in range(0,5000):
    if (row[i]==1):
        non_zero_elements_count=non_zero_elements_count+1
    
print(non_zero_elements_count)
# Out:
# 5

# %% [markdown]
# ## Task 4 - TF-IDF (5 points)
#
# The second approach extends the bag-of-words framework by taking into account total frequencies of words in the corpora. It helps to penalize too frequent words and provide better features space.
#
# Implement function *tfidf_features* using class  from *scikit-learn*. Use *train* corpus to train a vectorizer. Don't forget to take a look into the arguments that you can pass to it. We suggest that you filter out too rare words (occur less than in 5 titles) and too frequent words (occur more than in 90% of the titles). Also, use bigrams along with unigrams in your vocabulary.

# %% [markdown]
# ## Write a function which takes x_train, x_val and x_test as input and return the tf-idf features of the same and the vocabulary

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
print(x_train[:3])
# Out:
# ['draw stacked dotplot r', 'mysql select records datetime field less specified value', 'terminate windows phone 81 app']

# %%
def tfidf_features(x_train, x_val, x_test):
  
    tfidf_vectorizer = TfidfVectorizer(min_df=5,max_df=0.9,ngram_range=(1,2),token_pattern='(\S+)') #'(\S+)' means any no white space
    x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
    x_val_tfidf   = tfidf_vectorizer.transform(x_val)
    x_test_tfidf  = tfidf_vectorizer.transform(x_test)
    
    
    return x_train_tfidf, x_val_tfidf, x_test_tfidf, tfidf_vectorizer.vocabulary_

# %%
x_train_tfidf, x_val_tfidf, x_test_tfidf, tfidf_vocab = tfidf_features(x_train, x_val, x_test)
tfidf_reversed_vocab = {i:word for word,i in tfidf_vocab.items()}

# %% [markdown]
# Print the index of string "C#" in the vocabulary

# %%
tfidf_reversed_vocab
# Out:
# {4793: 'draw',
#  14939: 'stacked',
#  12746: 'r',
#  10392: 'mysql',
#  14017: 'select',
#  13006: 'records',
#  4090: 'datetime',
#  5815: 'field',
#  9075: 'less',
#  14799: 'specified',
#  17127: 'value',
#  10424: 'mysql select',
#  14052: 'select records',
#  4094: 'datetime field',
#  15704: 'terminate',
#  17847: 'windows',
#  11713: 'phone',
#  245: '81',
#  889: 'app',
#  17869: 'windows phone',
#  11716: 'phone 81',
#  246: '81 app',
#  6669: 'get',
#  3726: 'current',
#  15885: 'time',
#  14754: 'specific',
#  3532: 'country',
#  17417: 'via',
#  8649: 'jquery',
#  6700: 'get current',
#  3743: 'current time',
#  15914: 'time specific',
#  17431: 'via jquery',
#  3143: 'configuring',
#  15977: 'tomcat',
#  16670: 'use',
#  14925: 'ssl',
#  1380: 'awesome',
#  10549: 'nested',
#  14324: 'set',
#  11991: 'plugin',
#  417: 'add',
#  10614: 'new',
#  2591: 'children',
#  16057: 'tree',
#  17368: 'various',
#  9089: 'levels',
#  463: 'add new',
#  3555: 'create',
#  9680: 'map',
#  8771: 'json',
#  13396: 'response',
#  13690: 'ruby',
#  12775: 'rails',
#  148: '3',
#  8799: 'json response',
#  13705: 'ruby rails',
#  12777: 'rails 3',
#  13678: 'rspec',
#  15711: 'test',
#  9892: 'method',
#  2121: 'called',
#  13681: 'rspec test',
#  15721: 'test method',
#  9902: 'method called',
#  14856: 'springboot',
#  9116: 'lifecycle',
#  5500: 'exception',
#  7660: 'import',
#  3837: 'data',
#  5482: 'excel',
#  3953: 'database',
#  16799: 'using',
#  11727: 'php',
#  7663: 'import data',
#  3867: 'data excel',
#  10402: 'mysql database',
#  3983: 'database using',
#  16974: 'using php',
#  11007: 'obtaining',
#  10884: 'object',
#  11445: 'parameterized',
#  16214: 'type',
#  17918: 'without',
#  3237: 'constructing',
#  2629: 'class',
#  8161: 'ipad',
#  14091: 'selecting',
#  15734: 'text',
#  7909: 'inside',
#  7825: 'input',
#  15643: 'tap',
#  14096: 'selecting text',
#  15758: 'text inside',
#  15757: 'text input',
#  8742: 'jquerys',
#  6478: 'function',
#  6530: 'function object',
#  4957: 'eclipse',
#  1977: 'c++',
#  10001: 'mingw',
#  12341: 'program',
#  15705: 'terminated',
#  4959: 'eclipse c++',
#  8459: 'javascript',
#  2080: 'call',
#  11058: 'one',
#  12452: 'prototype',
#  781: 'another',
#  8473: 'javascript call',
#  2099: 'call one',
#  12453: 'prototype method',
#  9896: 'method another',
#  8087: 'intersection',
#  9240: 'list',
#  14386: 'sets',
#  9493: 'longer',
#  272: 'able',
#  7237: 'hide',
#  8896: 'keyboard',
#  8155: 'ios7',
#  5804: 'fetch',
#  8876: 'key',
#  15456: 'swift',
#  8807: 'json swift',
#  2366: 'change',
#  11939: 'pivot',
#  7161: 'header',
#  15680: 'template',
#  239: '8',
#  11715: 'phone 8',
#  3196: 'connectionstring',
#  5155: 'encryption',
#  9080: 'let',
#  16297: 'ui',
#  13096: 'refresh',
#  9483: 'long',
#  13751: 'running',
#  11201: 'operation',
#  9488: 'long running',
#  1564: 'better',
#  17596: 'way',
#  5536: 'execute',
#  5849: 'file',
#  12529: 'python',
#  3205: 'console',
#  11279: 'output',
#  13720: 'run',
#  1566: 'better way',
#  13700: 'ruby file',
#  5989: 'file using',
#  16987: 'using python',
#  12573: 'python get',
#  3210: 'console output',
#  5962: 'file run',
#  13743: 'run python',
#  9604: 'make',
#  87: '2',
#  15875: 'thumbnails',
#  2863: 'codeigniter',
#  8263: 'java',
#  2446: 'character',
#  17538: 'vs',
#  2436: 'char',
#  9835: 'memory',
#  16667: 'usage',
#  9849: 'memory usage',
#  1675: 'bootstrap',
#  10056: 'modal',
#  2793: 'close',
#  5187: 'enter',
#  12204: 'press',
#  1683: 'bootstrap modal',
#  5188: 'enter key',
#  8889: 'key press',
#  9208: 'linq',
#  12690: 'query',
#  7060: 'group',
#  13468: 'retrieving',
#  11676: 'percentage',
#  9224: 'linq query',
#  12698: 'query group',
#  8940: 'label',
#  8187: 'issue',
#  11175: 'openerp',
#  8862: 'keep',
#  10976: 'objects',
#  17454: 'view',
#  13851: 'scaling',
#  1388: 'axis',
#  1300: 'attributeerror',
#  10720: 'nonetype',
#  1286: 'attribute',
#  14816: 'split',
#  1303: 'attributeerror nonetype',
#  10721: 'nonetype object',
#  10890: 'object attribute',
#  920: 'append',
#  9731: 'mat',
#  13270: 'replace',
#  11047: 'onclick',
#  8717: 'jquery replace',
#  13031: 'redirect',
#  12364: 'programme',
#  13039: 'redirect output',
#  342: 'accesscontrolalloworigin',
#  12199: 'present',
#  13334: 'requested',
#  13379: 'resource',
#  5249: 'error',
#  343: 'accesscontrolalloworigin header',
#  13335: 'requested resource',
#  3615: 'creating',
#  1881: 'c#',
#  2159: 'cannot',
#  7657: 'implicitly',
#  3360: 'convert',
#  15125: 'string',
#  3628: 'creating json',
#  17850: 'windows 8',
#  241: '8 c#',
#  1960: 'c# using',
#  2181: 'cannot implicitly',
#  7658: 'implicitly convert',
#  3414: 'convert type',
#  16257: 'type string',
#  4630: 'django',
#  10093: 'modelform',
#  4648: 'django modelform',
#  14450: 'show',
#  4597: 'div',
#  14608: 'slide',
#  14460: 'show hide',
#  7239: 'hide div',
#  4617: 'div slide',
#  8576: 'javascript without',
#  17940: 'without jquery',
#  1374: 'avoid',
#  1793: 'busy',
#  8958: 'laravel',
#  179: '4',
#  13533: 'returns',
#  571: 'ajax',
#  12117: 'post',
#  8959: 'laravel 4',
#  3839: 'data ajax',
#  590: 'ajax post',
#  7107: 'handle',
#  8653: 'jquery ajax',
#  18254: 'year',
#  6542: 'function r',
#  13472: 'retrofit',
#  14570: 'singleton',
#  7072: 'gson',
#  16887: 'using gson',
#  3540: 'cpp',
#  9977: 'mfc',
#  3467: 'copying',
#  17665: 'web',
#  13064: 'reference',
#  12377: 'project',
#  17682: 'web reference',
#  10634: 'new project',
#  15993: 'top',
#  6186: 'five',
#  12714: 'query select',
#  7872: 'insert',
#  7729: 'index',
#  7893: 'insert string',
#  15227: 'string specific',
#  841: 'apache',
#  12008: 'poi',
#  11339: 'page',
#  6350: 'format',
#  18062: 'worksheet',
#  849: 'apache poi',
#  2401: 'change page',
#  5497: 'excel worksheet',
#  15950: 'tkinter',
#  12373: 'progress',
#  1441: 'bar',
#  12639: 'python tkinter',
#  12374: 'progress bar',
#  15068: 'store',
#  7536: 'image',
#  11607: 'path',
#  15074: 'store image',
#  7586: 'image path',
#  16825: 'using c#',
#  8593: 'jdbc',
#  3177: 'connection',
#  1249: 'associated',
#  9649: 'managed',
#  8594: 'jdbc connection',
#  3183: 'connection error',
#  10234: 'multiple',
#  15600: 'tables',
#  10066: 'model',
#  18265: 'yii2',
#  16710: 'use multiple',
#  10311: 'multiple tables',
#  15603: 'tables one',
#  11093: 'one model',
#  3328: 'controller',
#  10488: 'names',
#  1187: 'aspnet',
#  10384: 'mvc4',
#  1205: 'aspnet mvc4',
#  2291: 'casting',
#  8015: 'integer',
#  1018: 'array',
#  8016: 'integer array',
#  1090: 'array object',
#  10888: 'object array',
#  1074: 'array java',
#  6864: 'getting',
#  16615: 'uploading',
#  6873: 'getting error',
#  5375: 'error uploading',
#  16616: 'uploading file',
#  5949: 'file php',
#  2729: 'clear',
#  9965: 'methods',
#  9968: 'methods java',
#  12269: 'printing',
#  6227: 'floats',
#  10814: 'number',
#  18282: 'zeros',
#  14779: 'specific number',
#  14509: 'simple',
#  1855: 'c',
#  10602: 'network',
#  9099: 'library',
#  14512: 'simple c',
#  1857: 'c c++',
#  17066: 'usr',
#  1578: 'bin',
#  7991: 'instead',
#  9400: 'local',
#  13767: 'running ruby',
#  17067: 'usr bin',
#  17068: 'usr local',
#  1611: 'bitmap',
#  1580: 'binary',
#  11204: 'operations',
#  4192: 'default',
#  9576: 'mail',
#  18027: 'working',
#  5198: 'entity',
#  6416: 'framework',
#  4589: 'distinct',
#  5202: 'entity framework',
#  6430: 'framework model',
#  5693: 'extjs',
#  2551: 'checked',
#  10707: 'nodes',
#  15345: 'submit',
#  6687: 'get checked',
#  9314: 'lists',
#  9225: 'linq select',
#  10563: 'nested lists',
#  5020: 'element',
#  11528: 'pass',
#  17238: 'values',
#  7319: 'html',
#  7241: 'hide element',
#  11556: 'pass values',
#  17267: 'values javascript',
#  8513: 'javascript html',
#  7338: 'html element',
#  5044: 'element using',
#  16908: 'using javascript',
#  8520: 'javascript jquery',
#  7773: 'information',
#  4389: 'dictionary',
#  6738: 'get information',
#  14612: 'slidetoggle',
#  4532: 'display',
#  3608: 'created',
#  11168: 'opencv',
#  705: 'android',
#  4544: 'display image',
#  7988: 'instantiating',
#  10489: 'namespace',
#  18073: 'wpf',
#  13895: 'screen',
#  13369: 'resolution',
#  13897: 'screen resolution',
#  3276: 'content',
#  14992: 'static',
#  15563: 'table',
#  2322: 'cell',
#  4573: 'displayed',
#  8135: 'ios',
#  248: '9',
#  15598: 'table view',
#  17460: 'view cell',
#  8141: 'ios 9',
#  1551: 'best',
#  1338: 'autocomplete',
#  15401: 'suggest',
#  613: 'algorithm',
#  4033: 'datastructure',
#  1983: 'c++ c',
#  1404: 'backbone',
#  10097: 'modelsave',
#  14155: 'sending',
#  12506: 'put',
#  13052: 'redirects',
#  6915: 'given',
#  14299: 'session',
#  2601: 'chrome',
#  14312: 'session php',
#  10356: 'mvc',
#  12879: 'razor',
#  10018: 'missing',
#  2896: 'collections',
#  6291: 'form',
#  10360: 'mvc 4',
#  183: '4 razor',
#  6324: 'form post',
#  4045: 'date',
#  4131: 'ddmmyyyy',
#  15316: 'style',
#  4907: 'dynamically',
#  9192: 'linkbutton',
#  559: 'affecting',
#  11268: 'others',
#  2409: 'change style',
#  4918: 'dynamically created',
#  2487: 'check',
#  12012: 'point',
#  9135: 'line',
#  2767: 'client',
#  13306: 'request',
#  5770: 'fails',
#  15926: 'timeout',
#  14544: 'simultaneously',
#  368: 'acquire',
#  16552: 'update',
#  7015: 'graph',
#  9753: 'matplotlib',
#  3940: 'data update',
#  7018: 'graph using',
#  12595: 'python matplotlib',
#  15080: 'store value',
#  17218: 'value string',
#  15130: 'string array',
#  4034: 'datatable',
#  7818: 'inner',
#  8623: 'join',
#  4872: 'dynamic',
#  2952: 'columns',
#  1906: 'c# datatable',
#  7822: 'inner join',
#  4878: 'dynamic columns',
#  3478: 'correct',
#  415: 'adapter',
#  11626: 'pattern',
#  10966: 'objective',
#  10967: 'objective c',
#  13808: 'save',
#  6241: 'folder',
#  13817: 'save image',
#  7539: 'image another',
#  798: 'another folder',
#  6251: 'folder using',
#  16802: 'using ajax',
#  583: 'ajax jquery',
#  16694: 'use function',
#  7514: 'ignore',
#  13653: 'rows',
#  14716: 'sorting',
#  14788: 'specific rows',
#  4726: 'dom',
#  742: 'angular',
#  4476: 'directive',
#  4727: 'dom element',
#  746: 'angular directive',
#  13015: 'rectangles',
#  10662: 'next',
#  11448: 'parameters',
#  16629: 'url',
#  18278: 'zend',
#  11455: 'parameters url',
#  7777: 'inheritance',
#  300: 'access',
#  12291: 'problem',
#  7819: 'inner class',
#  17236: 'valueerror',
#  9732: 'match',
#  11568: 'passing',
#  14672: 'sockets',
#  11572: 'passing array',
#  1077: 'array json',
#  8790: 'json objects',
#  2573: 'child',
#  4310: 'deserializing',
#  18190: 'xml',
#  2580: 'child nodes',
#  4312: 'deserializing xml',
#  18210: 'xml object',
#  17401: 'version',
#  942: 'application',
#  5533: 'executable',
#  3268: 'contains',
#  16541: 'unsupported',
#  985: 'architecture',
#  7440: 'i386',
#  909: 'app version',
#  986: 'architecture i386',
#  2964: 'com',
#  1117: 'array using',
#  16838: 'using com',
#  16660: 'urlopen',
#  5246: 'errno',
#  54: '10061',
#  5293: 'error errno',
#  16468: 'unique',
#  2967: 'combination',
#  1591: 'bind',
#  4817: 'drop',
#  6159: 'first',
#  4130: 'ddl',
#  4820: 'drop list',
#  9293: 'list using',
#  16914: 'using jquery',
#  2383: 'change first',
#  160: '31',
#  5152: 'encrypted',
#  6615: 'gem',
#  2719: 'clause',
#  5836: 'fields',
#  12779: 'rails 31',
#  7100: 'hack',
#  6967: 'google',
#  9699: 'maps',
#  855: 'api',
#  6624: 'generate',
#  2624: 'city',
#  14978: 'state',
#  10455: 'name',
#  11818: 'php mysql',
#  6980: 'google maps',
#  9700: 'maps api',
#  2625: 'city state',
#  16493: 'unknown',
#  15646: 'target',
#  12412: 'property',
#  938: 'applet',
#  9554: 'mac',
#  11261: 'os',
#  13734: 'run java',
#  8275: 'java applet',
#  9556: 'mac os',
#  9017: 'latitude',
#  9497: 'longitude',
#  9018: 'latitude longitude',
#  10166: 'mouseout',
#  9307: 'listener',
#  17988: 'wordpress',
#  6979: 'google map',
#  6068: 'find',
#  13619: 'row',
#  12738: 'quickly',
#  6111: 'find row',
#  8164: 'iphone',
#  2991: 'command',
#  15703: 'terminal',
#  13474: 'return',
#  9757: 'matrix',
#  10531: 'need',
#  16049: 'transpose',
#  1271: 'attach',
#  3996: 'dataframe',
#  11459: 'parent',
#  12355: 'programmatically',
#  3825: 'd3',
#  8746: 'js',
#  15877: 'tick',
#  14739: 'spacing',
#  6859: 'gets',
#  9884: 'messed',
#  10142: 'month',
#  1701: 'boundary',
#  7140: 'hash',
#  10919: 'object javascript',
#  14375: 'set timeout',
#  16747: 'user',
#  6183: 'fit',
#  10540: 'needs',
#  2378: 'change default',
#  16771: 'user model',
#  14219: 'serializing',
#  1356: 'automatically',
#  7952: 'install',
#  6150: 'firefox',
#  10513: 'navbar',
#  1326: 'auto',
#  9025: 'layout',
#  3234: 'constraints',
#  8049: 'interactive',
#  8054: 'interface',
#  1775: 'builder',
#  1332: 'auto layout',
#  8056: 'interface builder',
#  8919: 'kill',
#  12307: 'process',
#  15518: 'system',
#  14430: 'shell',
#  2585: 'child process',
#  12315: 'process running',
#  14431: 'shell command',
#  14393: 'setting',
#  15939: 'timezone',
#  2209: 'cant',
#  12982: 'recent',
#  2239: 'cant update',
#  5717: 'facebook',
#  7193: 'help',
#  4379: 'dialog',
#  5418: 'event',
#  9346: 'load',
#  1755: 'browsers',
#  8683: 'jquery event',
#  5436: 'event listener',
#  7577: 'image load',
#  8040: 'intellij',
#  3222: 'constant',
#  5643: 'expression',
#  13343: 'required',
#  2277: 'case',
#  721: 'android java',
#  3225: 'constant expression',
#  4826: 'dropdown',
#  1467: 'based',
#  5208: 'entries',
#  4832: 'dropdown select',
#  14019: 'select based',
#  1475: 'based database',
#  17970: 'wont',
#  18002: 'work',
#  9558: 'machine',
#  17977: 'wont work',
#  9407: 'local machine',
#  12524: 'pyqt',
#  4537: 'display data',
#  3898: 'data mysql',
#  3980: 'database table',
#  15595: 'table using',
#  487: 'addeventlistener',
#  14124: 'send',
#  15834: 'thread',
#  14128: 'send data',
#  3927: 'data specific',
#  6236: 'focus',
#  9330: 'listviewitem',
#  4695: 'documentgetelementbyid',
#  7823: 'innerhtml',
#  7494: 'ie8',
#  18041: 'working ie8',
#  5001: 'efficient',
#  7996: 'int',
#  8118: 'inverse',
#  3407: 'convert string',
#  15186: 'string int',
#  4978: 'edit',
#  16212: 'txt',
#  14776: 'specific line',
#  9161: 'line txt',
#  16213: 'txt file',
#  5867: 'file c',
#  3127: 'conditionally',
#  6054: 'filter',
#  8177: 'iqueryable',
#  6646: 'generic',
#  13299: 'repository',
#  16264: 'type using',
#  16875: 'using generic',
#  6657: 'generic repository',
#  13300: 'repository pattern',
#  6762: 'get memory',
#  12788: 'rails app',
#  8096: 'invalid',
#  7757: 'indirect',
#  16108: 'trying',
#  16114: 'trying convert',
#  2010: 'c++ java',
#  13000: 'record',
#  7884: 'insert multiple',
#  13003: 'record table',
#  15569: 'table codeigniter',
#  14867: 'sql',
#  3405: 'convert sql',
#  14884: 'sql query',
#  12702: 'query linq',
#  11595: 'password',
#  12396: 'prompt',
#  13111: 'regex',
#  10539: 'needed',
#  4895: 'dynamic string',
#  15240: 'string value',
#  11963: 'play',
#  17452: 'videos',
#  17731: 'website',
#  1561: 'best way',
#  12939: 'reading',
#  15034: 'stdin',
#  1640: 'blocking',
#  12947: 'reading line',
#  9154: 'line line',
#  17922: 'without blocking',
#  17442: 'video',
#  11038: 'old',
#  13412: 'rest',
#  13413: 'rest api',
#  2987: 'comma',
#  14184: 'separated',
#  2889: 'collection',
#  14829: 'spring',
#  2989: 'comma separated',
#  14188: 'separated string',
#  15189: 'string java',
#  8293: 'java collection',
#  14844: 'spring form',
#  2559: 'checking',
#  9821: 'member',
#  15275: 'struct',
#  1876: 'c struct',
#  15276: 'struct array',
#  7044: 'gridview',
#  5629: 'export',
#  7049: 'gridview data',
#  5632: 'export excel',
#  15942: 'tinymce',
#  11974: 'player',
#  9812: 'media',
#  14813: 'splash',
#  296: 'accepts',
#  2694: 'class use',
#  16730: 'use spring',
#  3699: 'csv',
#  15262: 'stringsplit',
#  4851: 'due',
#  1624: 'blank',
#  7662: 'import csv',
#  3701: 'csv file',
#  9091: 'li',
#  10678: 'ngmodel',
#  14962: 'start',
#  1622: 'blackberry',
#  12366: 'programming',
#  13980: 'searching',
#  13955: 'sdk',
#  12734: 'quick',
#  8169: 'iphone sdk',
#  4482: 'directory',
#  1924: 'c# get',
#  4489: 'directory name',
#  2920: 'column',
#  11028: 'odd',
#  5413: 'even',
#  10851: 'numbers',
#  15850: 'threads',
#  11029: 'odd even',
#  5414: 'even numbers',
#  10863: 'numbers using',
#  16800: 'using 2',
#  670: 'alternatives',
#  12393: 'projects',
#  14507: 'similar',
#  8634: 'joomla',
#  4845: 'drupal',
#  1237: 'assign',
#  17298: 'variable',
#  12406: 'properties',
#  1913: 'c# dynamic',
#  4904: 'dynamic variable',
#  4894: 'dynamic object',
#  6777: 'get parameters',
#  5833: 'field value',
#  17196: 'value object',
#  806: 'another object',
#  347: 'accessing',
#  6932: 'global',
#  11055: 'onclicklistener',
#  349: 'accessing global',
#  6937: 'global variable',
#  17316: 'variable inside',
#  995: 'argument',
#  16359: 'uml',
#  999: 'argument list',
#  12184: 'preg_replace',
#  3721: 'curly',
#  1722: 'brackets',
#  166: '323',
#  1788: 'bundler',
#  3494: 'could',
#  3042: 'compatible',
#  17410: 'versions',
#  12781: 'rails 323',
#  3502: 'could find',
#  5529: 'exe',
#  1967: 'c# windows',
#  17862: 'windows form',
#  8846: 'junit',
#  13291: 'report',
#  15650: 'task',
#  5736: 'facebooks',
#  14631: 'sms',
#  1735: 'broadcast',
#  12978: 'receiver',
#  15635: 'takes',
#  7256: 'highest',
#  12276: 'priority',
#  12971: 'reboot',
#  9067: 'length',
#  27: '0',
#  1844: 'bypass',
#  2783: 'clientside',
#  17108: 'validation',
#  2784: 'clientside validation',
#  13785: 'rvm',
#  7961: 'installation',
#  16288: 'ubuntu',
#  7962: 'installation error',
#  5367: 'error ubuntu',
#  16076: 'trigger',
#  2267: 'carousel',
#  16079: 'trigger event',
#  1678: 'bootstrap carousel',
#  12463: 'proxy',
#  3134: 'configuration',
#  16360: 'unable',
#  13053: 'redirecttoaction',
#  2223: 'cant get',
#  8235: 'iterators',
#  7705: 'incompatible',
#  4327: 'destruction',
#  4279: 'dependent',
#  3239: 'constructor',
#  3240: 'constructor call',
#  1431: 'bad',
#  7847: 'input line',
#  15492: 'symfony2',
#  6381: 'forms',
#  11229: 'options',
#  16689: 'use dynamic',
#  14049: 'select options',
#  10749: 'notfoundhttpexception',
#  15344: 'submission',
#  7121: 'handling',
#  17118: 'validation multiple',
#  10261: 'multiple forms',
#  16085: 'triggers',
#  11232: 'oracle',
#  10136: 'mongoose',
#  2115: 'callback',
#  329: 'access specific',
#  14794: 'specific value',
#  17765: 'well',
#  16585: 'updating',
#  10094: 'models',
#  205: '5',
#  2242: 'canvas',
#  8191: 'issues',
#  7320: 'html 5',
#  3039: 'comparison',
#  17344: 'variables',
#  12034: 'pointing',
#  11478: 'parse',
#  11484: 'parse json',
#  8775: 'json data',
#  3905: 'data php',
#  12100: 'possible',
#  8844: 'jump',
#  15998: 'top page',
#  11353: 'page form',
#  6331: 'form submit',
#  13797: 'safely',
#  4325: 'destroy',
#  17818: 'window',
#  18144: 'wxpython',
#  7701: 'includes',
#  15546: 'systems',
#  11796: 'php includes',
#  9652: 'managepy',
#  13775: 'runserver',
#  9653: 'managepy runserver',
#  13830: 'saving',
#  6415: 'frames',
#  13838: 'saving multiple',
#  10250: 'multiple data',
#  3874: 'data frames',
#  13486: 'return function',
#  3043: 'compilation',
#  6398: 'found',
#  3044: 'compilation error',
#  5365: 'error type',
#  16247: 'type namespace',
#  10491: 'namespace name',
#  3503: 'could found',
#  11488: 'parsecom',
#  9095: 'libgdx',
#  7646: 'implementation',
#  7501: 'iframe',
#  12088: 'position',
#  489: 'adding',
#  8463: 'javascript adding',
#  510: 'adding text',
#  15756: 'text image',
#  7611: 'image using',
#  16829: 'using canvas',
#  13823: 'save value',
#  17159: 'value drop',
#  2063: 'calculate',
#  3484: 'correlation',
#  13193: 'remove',
#  11124: 'ones',
#  11404: 'pandas',
#  12609: 'python pandas',
#  11217: 'optimizations',
#  1740: 'browser',
#  11680: 'perform',
#  13254: 'rendered',
#  4268: 'denied',
#  14268: 'service',
#  4228: 'delegate',
#  9579: 'mail client',
#  2779: 'client using',
#  3517: 'count',
#  4011: 'datagridview',
#  17248: 'values column',
#  2930: 'column datagridview',
#  4015: 'datagridview column',
#  13879: 'scipy',
#  1769: 'build',
#  11266: 'osx',
#  9557: 'mac osx',
#  8158: 'ip',
#  516: 'address',
#  9723: 'mask',
#  15792: 'textbox',
#  8159: 'ip address',
#  17376: 'vbnet',
#  3005: 'commands',
#  8343: 'java library',
#  14068: 'selected',
#  2857: 'codebehind',
#  6808: 'get selected',
#  14084: 'selected value',
#  17220: 'value text',
#  15755: 'text html',
#  7362: 'html select',
#  13432: 'restrict',
#  8648: 'jqgrid',
#  15787: 'textarea',
#  7182: 'height',
#  7035: 'grid',
#  15459: 'swift 3',
#  4988: 'editor',
#  14208: 'serialization',
#  18218: 'xml serialization',
#  5661: 'extend',
#  8289: 'java class',
#  2679: 'class one',
#  5520: 'exceptions',
#  7090: 'guidelines',
#  16430: 'understand',
#  15730: 'testng',
#  15406: 'suite',
#  3141: 'configure',
#  17720: 'webpage',
#  5487: 'excel data',
#  11425: 'parameter',
#  11324: 'owin',
#  7287: 'host',
#  11548: 'pass parameter',
#  13827: 'saved',
#  12832: 'rake',
#  5386: 'errors',
#  9384: 'loading',
#  8923: 'kind',
#  10353: 'mutex',
#  2075: 'calculation',
#  5195: 'entities',
#  9212: 'linq entities',
#  5196: 'entities query',
#  4409: 'difference',
#  2824: 'cocos2dx',
#  9544: 'lua',
#  1596: 'binding',
#  13355: 'reset',
#  754: 'angularjs',
#  17398: 'verify',
#  1707: 'box',
#  2758: 'clicked',
#  2489: 'check box',
#  15284: 'structure',
#  12016: 'pointer',
#  ...}

# %%
type(tfidf_reversed_vocab)
# Out:
# dict

# %%
keys=tfidf_reversed_vocab.keys(); keys
# Out:
# dict_keys([4793, 14939, 12746, 10392, 14017, 13006, 4090, 5815, 9075, 14799, 17127, 10424, 14052, 4094, 15704, 17847, 11713, 245, 889, 17869, 11716, 246, 6669, 3726, 15885, 14754, 3532, 17417, 8649, 6700, 3743, 15914, 17431, 3143, 15977, 16670, 14925, 1380, 10549, 14324, 11991, 417, 10614, 2591, 16057, 17368, 9089, 463, 3555, 9680, 8771, 13396, 13690, 12775, 148, 8799, 13705, 12777, 13678, 15711, 9892, 2121, 13681, 15721, 9902, 14856, 9116, 5500, 7660, 3837, 5482, 3953, 16799, 11727, 7663, 3867, 10402, 3983, 16974, 11007, 10884, 11445, 16214, 17918, 3237, 2629, 8161, 14091, 15734, 7909, 7825, 15643, 14096, 15758, 15757, 8742, 6478, 6530, 4957, 1977, 10001, 12341, 15705, 4959, 8459, 2080, 11058, 12452, 781, 8473, 2099, 12453, 9896, 8087, 9240, 14386, 9493, 272, 7237, 8896, 8155, 5804, 8876, 15456, 8807, 2366, 11939, 7161, 15680, 239, 11715, 3196, 5155, 9080, 16297, 13096, 9483, 13751, 11201, 9488, 1564, 17596, 5536, 5849, 12529, 3205, 11279, 13720, 1566, 13700, 5989, 16987, 12573, 3210, 5962, 13743, 9604, 87, 15875, 2863, 8263, 2446, 17538, 2436, 9835, 16667, 9849, 1675, 10056, 2793, 5187, 12204, 1683, 5188, 8889, 9208, 12690, 7060, 13468, 11676, 9224, 12698, 8940, 8187, 11175, 8862, 10976, 17454, 13851, 1388, 1300, 10720, 1286, 14816, 1303, 10721, 10890, 920, 9731, 13270, 11047, 8717, 13031, 12364, 13039, 342, 12199, 13334, 13379, 5249, 343, 13335, 3615, 1881, 2159, 7657, 3360, 15125, 3628, 17850, 241, 1960, 2181, 7658, 3414, 16257, 4630, 10093, 4648, 14450, 4597, 14608, 14460, 7239, 4617, 8576, 17940, 1374, 1793, 8958, 179, 13533, 571, 12117, 8959, 3839, 590, 7107, 8653, 18254, 6542, 13472, 14570, 7072, 16887, 3540, 9977, 3467, 17665, 13064, 12377, 17682, 10634, 15993, 6186, 12714, 7872, 7729, 7893, 15227, 841, 12008, 11339, 6350, 18062, 849, 2401, 5497, 15950, 12373, 1441, 12639, 12374, 15068, 7536, 11607, 15074, 7586, 16825, 8593, 3177, 1249, 9649, 8594, 3183, 10234, 15600, 10066, 18265, 16710, 10311, 15603, 11093, 3328, 10488, 1187, 10384, 1205, 2291, 8015, 1018, 8016, 1090, 10888, 1074, 6864, 16615, 6873, 5375, 16616, 5949, 2729, 9965, 9968, 12269, 6227, 10814, 18282, 14779, 14509, 1855, 10602, 9099, 14512, 1857, 17066, 1578, 7991, 9400, 13767, 17067, 17068, 1611, 1580, 11204, 4192, 9576, 18027, 5198, 6416, 4589, 5202, 6430, 5693, 2551, 10707, 15345, 6687, 9314, 9225, 10563, 5020, 11528, 17238, 7319, 7241, 11556, 17267, 8513, 7338, 5044, 16908, 8520, 7773, 4389, 6738, 14612, 4532, 3608, 11168, 705, 4544, 7988, 10489, 18073, 13895, 13369, 13897, 3276, 14992, 15563, 2322, 4573, 8135, 248, 15598, 17460, 8141, 1551, 1338, 15401, 613, 4033, 1983, 1404, 10097, 14155, 12506, 13052, 6915, 14299, 2601, 14312, 10356, 12879, 10018, 2896, 6291, 10360, 183, 6324, 4045, 4131, 15316, 4907, 9192, 559, 11268, 2409, 4918, 2487, 12012, 9135, 2767, 13306, 5770, 15926, 14544, 368, 16552, 7015, 9753, 3940, 7018, 12595, 15080, 17218, 15130, 4034, 7818, 8623, 4872, 2952, 1906, 7822, 4878, 3478, 415, 11626, 10966, 10967, 13808, 6241, 13817, 7539, 798, 6251, 16802, 583, 16694, 7514, 13653, 14716, 14788, 4726, 742, 4476, 4727, 746, 13015, 10662, 11448, 16629, 18278, 11455, 7777, 300, 12291, 7819, 17236, 9732, 11568, 14672, 11572, 1077, 8790, 2573, 4310, 18190, 2580, 4312, 18210, 17401, 942, 5533, 3268, 16541, 985, 7440, 909, 986, 2964, 1117, 16838, 16660, 5246, 54, 5293, 16468, 2967, 1591, 4817, 6159, 4130, 4820, 9293, 16914, 2383, 160, 5152, 6615, 2719, 5836, 12779, 7100, 6967, 9699, 855, 6624, 2624, 14978, 10455, 11818, 6980, 9700, 2625, 16493, 15646, 12412, 938, 9554, 11261, 13734, 8275, 9556, 9017, 9497, 9018, 10166, 9307, 17988, 6979, 6068, 13619, 12738, 6111, 8164, 2991, 15703, 13474, 9757, 10531, 16049, 1271, 3996, 11459, 12355, 3825, 8746, 15877, 14739, 6859, 9884, 10142, 1701, 7140, 10919, 14375, 16747, 6183, 10540, 2378, 16771, 14219, 1356, 7952, 6150, 10513, 1326, 9025, 3234, 8049, 8054, 1775, 1332, 8056, 8919, 12307, 15518, 14430, 2585, 12315, 14431, 14393, 15939, 2209, 12982, 2239, 5717, 7193, 4379, 5418, 9346, 1755, 8683, 5436, 7577,  ...

# %%
values=tfidf_reversed_vocab.values(); values
# Out:
# dict_values(['draw', 'stacked', 'r', 'mysql', 'select', 'records', 'datetime', 'field', 'less', 'specified', 'value', 'mysql select', 'select records', 'datetime field', 'terminate', 'windows', 'phone', '81', 'app', 'windows phone', 'phone 81', '81 app', 'get', 'current', 'time', 'specific', 'country', 'via', 'jquery', 'get current', 'current time', 'time specific', 'via jquery', 'configuring', 'tomcat', 'use', 'ssl', 'awesome', 'nested', 'set', 'plugin', 'add', 'new', 'children', 'tree', 'various', 'levels', 'add new', 'create', 'map', 'json', 'response', 'ruby', 'rails', '3', 'json response', 'ruby rails', 'rails 3', 'rspec', 'test', 'method', 'called', 'rspec test', 'test method', 'method called', 'springboot', 'lifecycle', 'exception', 'import', 'data', 'excel', 'database', 'using', 'php', 'import data', 'data excel', 'mysql database', 'database using', 'using php', 'obtaining', 'object', 'parameterized', 'type', 'without', 'constructing', 'class', 'ipad', 'selecting', 'text', 'inside', 'input', 'tap', 'selecting text', 'text inside', 'text input', 'jquerys', 'function', 'function object', 'eclipse', 'c++', 'mingw', 'program', 'terminated', 'eclipse c++', 'javascript', 'call', 'one', 'prototype', 'another', 'javascript call', 'call one', 'prototype method', 'method another', 'intersection', 'list', 'sets', 'longer', 'able', 'hide', 'keyboard', 'ios7', 'fetch', 'key', 'swift', 'json swift', 'change', 'pivot', 'header', 'template', '8', 'phone 8', 'connectionstring', 'encryption', 'let', 'ui', 'refresh', 'long', 'running', 'operation', 'long running', 'better', 'way', 'execute', 'file', 'python', 'console', 'output', 'run', 'better way', 'ruby file', 'file using', 'using python', 'python get', 'console output', 'file run', 'run python', 'make', '2', 'thumbnails', 'codeigniter', 'java', 'character', 'vs', 'char', 'memory', 'usage', 'memory usage', 'bootstrap', 'modal', 'close', 'enter', 'press', 'bootstrap modal', 'enter key', 'key press', 'linq', 'query', 'group', 'retrieving', 'percentage', 'linq query', 'query group', 'label', 'issue', 'openerp', 'keep', 'objects', 'view', 'scaling', 'axis', 'attributeerror', 'nonetype', 'attribute', 'split', 'attributeerror nonetype', 'nonetype object', 'object attribute', 'append', 'mat', 'replace', 'onclick', 'jquery replace', 'redirect', 'programme', 'redirect output', 'accesscontrolalloworigin', 'present', 'requested', 'resource', 'error', 'accesscontrolalloworigin header', 'requested resource', 'creating', 'c#', 'cannot', 'implicitly', 'convert', 'string', 'creating json', 'windows 8', '8 c#', 'c# using', 'cannot implicitly', 'implicitly convert', 'convert type', 'type string', 'django', 'modelform', 'django modelform', 'show', 'div', 'slide', 'show hide', 'hide div', 'div slide', 'javascript without', 'without jquery', 'avoid', 'busy', 'laravel', '4', 'returns', 'ajax', 'post', 'laravel 4', 'data ajax', 'ajax post', 'handle', 'jquery ajax', 'year', 'function r', 'retrofit', 'singleton', 'gson', 'using gson', 'cpp', 'mfc', 'copying', 'web', 'reference', 'project', 'web reference', 'new project', 'top', 'five', 'query select', 'insert', 'index', 'insert string', 'string specific', 'apache', 'poi', 'page', 'format', 'worksheet', 'apache poi', 'change page', 'excel worksheet', 'tkinter', 'progress', 'bar', 'python tkinter', 'progress bar', 'store', 'image', 'path', 'store image', 'image path', 'using c#', 'jdbc', 'connection', 'associated', 'managed', 'jdbc connection', 'connection error', 'multiple', 'tables', 'model', 'yii2', 'use multiple', 'multiple tables', 'tables one', 'one model', 'controller', 'names', 'aspnet', 'mvc4', 'aspnet mvc4', 'casting', 'integer', 'array', 'integer array', 'array object', 'object array', 'array java', 'getting', 'uploading', 'getting error', 'error uploading', 'uploading file', 'file php', 'clear', 'methods', 'methods java', 'printing', 'floats', 'number', 'zeros', 'specific number', 'simple', 'c', 'network', 'library', 'simple c', 'c c++', 'usr', 'bin ...

# %%
# note - 'C#' is not there in the dictionary vocab but 'c#' is
{k:v for k, v in tfidf_reversed_vocab.items() if v == 'c#'}
# Out:
# {1881: 'c#'}

# %% [markdown]
# ## Task 5: Classification (15 points)
# MultiLabel classifier
#
# As we have noticed before, in this task each example can have multiple tags. To deal with such kind of prediction, we need to transform labels in a binary form and the prediction will be a mask of 0s and 1s. For this purpose it is convenient to use MultiLabelBinarizer from sklearn. <br>
# <u>Documentation:</u> <br>
# http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MultiLabelBinarizer.html

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
mlb = MultiLabelBinarizer(classes=sorted(tags_counts.keys()))
y_train = mlb.fit_transform(y_train)
y_val = mlb.fit_transform(y_val)

# %% [markdown]
# In this task we suggest to use One-vs-Rest approach, which is implemented in [OneVsRestClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multiclass.OneVsRestClassifier.html) class. In this approach *k* classifiers (= number of tags) are trained. As a basic classifier, use [LogisticRegression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html). It is one of the simplest methods, but often it performs good enough in text classification tasks. It might take some time, because a number of classifiers to train is large.
#
# **OneVsRest multi-label strategy**
#
# The Multi-label algorithm accepts a binary mask over multiple labels. The result for each prediction will be an array of 0s and 1s marking which class labels apply to each row input sample.
#
# **Logistic Regression & SVM**
#
# OneVsRest strategy can be used for multi-label learning, where a classifier is used to predict multiple labels for instance. LR & SVM supports multi-class, but we are in a multi-label scenario, therefore, we wrap classifiers in the OneVsRestClassifier.
#
# *If you want to learn more about OneVsRest, check out these links:*
# - *https://towardsdatascience.com/multi-label-text-classification-with-scikit-learn-30714b7819c5*
# - *https://towardsdatascience.com/journey-to-the-center-of-multi-label-classification-384c40229bff*
# - *https://medium.com/coinmonks/multi-label-classification-blog-tags-prediction-using-nlp-b0b5ee6686fc*

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC

# %%
def train_classifier(X_train, y_train):
    # Create and fit LogisticRegression and LinearSVC wraped into OneVsRestClassifier.

    model = OneVsRestClassifier(LogisticRegression()).fit(X_train,y_train) 
    clf = model
    
    return clf  ### clf is the model

# %% [markdown]
# Train the classifiers for different data transformations: *bag-of-words* and *tf-idf*.
# classifier_mybag = model for

# %%
classifier_mybag = train_classifier(x_train_mybag, y_train)
classifier_tfidf = train_classifier(x_train_tfidf, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# Now you can create predictions for the data. You will need two types of predictions: labels and scores.

# %%
y_val_predicted_labels_mybag = classifier_mybag.predict(x_val_mybag)
y_val_predicted_scores_mybag = classifier_mybag.decision_function(x_val_mybag)

y_val_predicted_labels_tfidf = classifier_tfidf.predict(x_val_tfidf)
y_val_predicted_scores_tfidf = classifier_tfidf.decision_function(x_val_tfidf)

# %% [markdown]
# Now, we would need to compare the results of different predictions, e.g. to see whether TF-IDF transformation helps or to try different regularization techniques in logistic regression. For all these experiments, we need to setup evaluation procedure.

# %% [markdown]
# ## Evaluation (10 points)
#
# To evaluate the results we will use several classification metrics:
#  - [Accuracy](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)
#  - [F1-score](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html)
#  - [Area under ROC-curve](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html)
#  - [Area under precision-recall curve](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.average_precision_score.html#sklearn.metrics.average_precision_score)
#
# Make sure you are familiar with all of them. If you want a refresher, you can click the link to their documentation

# %% [markdown]
# ## Import the necessary libraries for the above metrics

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import average_precision_score
from sklearn.metrics import recall_score

# %% [markdown]
# Define the function *print_evaluation_scores* which takes y_val and predicted as input calculates and prints the following output:
#  - *accuracy*
#  - *F1-score - Average = 'weighted'*
#  - *Precision - Average = 'macro'*

# %%
def print_evaluation_scores(y_val, predicted):
  
    accuracy=accuracy_score(y_val, predicted)
    f1_score_macro=f1_score(y_val, predicted, average='macro')
    f1_score_micro=f1_score(y_val, predicted, average='micro')
    f1_score_weighted=f1_score(y_val, predicted, average='weighted')
    precision_macro=average_precision_score(y_val, predicted, average='macro')
    precision_micro=average_precision_score(y_val, predicted, average='micro')
    precision_weighted=average_precision_score(y_val, predicted, average='weighted')
    print(accuracy,f1_score_macro,f1_score_micro,f1_score_weighted,precision_macro,precision_micro,precision_weighted)

# %%
print('Bag-of-words')
print_evaluation_scores(y_val, y_val_predicted_labels_mybag)
print('Tfidf')
print_evaluation_scores(y_val, y_val_predicted_labels_tfidf)
# Out:
# Bag-of-words
# 0.339 0.5008894063629369 0.6544559124011107 0.6321515244426389 0.34034445888066445 0.4604978227073275 0.4921816279645647
# Tfidf
# 0.3339666666666667 0.445626959589763 0.6418155543878087 0.6143448694553224 0.30198777439820335 0.45699911454931047 0.4851096962813454

# %% [markdown]
# You might also want to plot some form of the [ROC curve](http://scikit-learn.org/stable/modules/model_evaluation.html#receiver-operating-characteristic-roc) for the case of multi-label classification. The input parameters for the roc curve are:
#  - true labels
#  - decision functions scores
#  - number of classes

# %% [markdown]
# Import the roc_auc function from the metrics.py file provided

# %%
import os
os.chdir('/content/drive/My Drive/NLP/Statistical NLP')

# %%
import metrics
from metrics import roc_auc
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
n_classes = len(tags_counts)
roc_auc(y_val, y_val_predicted_scores_mybag, n_classes)

# %%
n_classes = len(tags_counts)
roc_auc(y_val, y_val_predicted_scores_tfidf, n_classes)

# %% [markdown]
# **Now for SVC**

# %%
def train_classifier(X_train, y_train):
    # Create and fit LogisticRegression and LinearSVC wraped into OneVsRestClassifier.

    model = OneVsRestClassifier(LinearSVC(), n_jobs=1).fit(X_train,y_train) 
    clf = model
    
    return clf  ### clf is the model

# %%
classifier_mybag = train_classifier(x_train_mybag, y_train)
classifier_tfidf = train_classifier(x_train_tfidf, y_train)

# %%
y_val_predicted_labels_mybag = classifier_mybag.predict(x_val_mybag)
y_val_predicted_scores_mybag = classifier_mybag.decision_function(x_val_mybag)

y_val_predicted_labels_tfidf = classifier_tfidf.predict(x_val_tfidf)
y_val_predicted_scores_tfidf = classifier_tfidf.decision_function(x_val_tfidf)

# %%
print('Bag-of-words')
print_evaluation_scores(y_val, y_val_predicted_labels_mybag)
print('Tfidf')
print_evaluation_scores(y_val, y_val_predicted_labels_tfidf)
# Out:
# Bag-of-words
# 0.3458333333333333 0.5173045392732116 0.6625746821222489 0.6423135201160223 0.34780700705748346 0.4650707769687501 0.4971693639190863
# Tfidf
# 0.3761333333333333 0.5206503052031404 0.6848877541678957 0.661414429633502 0.3595346025877641 0.4949786549008852 0.5216213995456508

# %%
n_classes = len(tags_counts)
roc_auc(y_val, y_val_predicted_scores_mybag, n_classes)

# %%
n_classes = len(tags_counts)
roc_auc(y_val, y_val_predicted_scores_tfidf, n_classes)

# %% [markdown]
# ## Task 4 (MultilabelClassification) - Optional
# ** Once we have the evaluation set up, we suggest that you experiment a bit with training your classifiers. We will use *F1-score weighted* as an evaluation metric. Our recommendation:
# - compare the quality of the bag-of-words and TF-IDF approaches and chose one of them.
# - for the chosen one, try *L1* and *L2*-regularization techniques in Logistic Regression with different coefficients (e.g. C equal to 0.1, 1, 10, 100).

# %%
def train_classifier(x_train, y_train):
  
  model=OneVsRestClassifier(LogisticRegression(penalty="l1",C=1)).fit(x_train,y_train)
  
  return model

# %%
classifier_mybag = train_classifier(x_train_mybag, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
y_val_predicted_labels_mybag = classifier_mybag.predict(x_val_mybag)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import average_precision_score
from sklearn.metrics import recall_score

# %%
def print_evaluation_scores(y_val, predicted):
    accuracy=accuracy_score(y_val, predicted)
    f1_score_macro=f1_score(y_val, predicted, average='macro')
    f1_score_micro=f1_score(y_val, predicted, average='micro')
    f1_score_weighted=f1_score(y_val, predicted, average='weighted')
    precision_macro=average_precision_score(y_val, predicted, average='macro')
    precision_micro=average_precision_score(y_val, predicted, average='micro')
    precision_weighted=average_precision_score(y_val, predicted, average='weighted')
    print(accuracy,f1_score_macro,f1_score_micro,f1_score_weighted,precision_macro,precision_micro,precision_weighted)

# %%
print('Bag-of-words')
print_evaluation_scores(y_val, y_val_predicted_labels_mybag)
# Out:
# Bag-of-words
# 0.34536666666666666 0.513982451155037 0.6612924979509686 0.6393336946110989 0.351071370610742 0.46718907296759804 0.49890583137758904

# %% [markdown]
# When you are happy with the quality, create predictions for *test* set.

# %%
test_predictions = classifier_mybag.predict(x_test_mybag)
test_pred_inversed = mlb.inverse_transform(test_predictions)

test_predictions_for_submission = '\n'.join('%i\t%s' % (i, ','.join(row)) for i, row in enumerate(test_pred_inversed))
test_predictions_for_submission
# Out:
# '0\tmysql,php\n1\tjavascript\n2\t\n3\tjavascript,jquery\n4\tandroid,java\n5\tphp,xml\n6\tjson,web-services\n7\tjava,swing\n8\tpython\n9\thtml\n10\tjquery\n11\t\n12\tphp\n13\truby-on-rails\n14\tc#\n15\tpython,python-2.7\n16\t\n17\tajax,html,javascript,jquery,ruby-on-rails\n18\t\n19\tc++,linux,sockets\n20\tpython\n21\tpandas,python\n22\t\n23\t\n24\tphp,wordpress\n25\tc++\n26\truby,ruby-on-rails\n27\tc#,wpf\n28\tpython\n29\tr\n30\tjavascript,jquery\n31\tc#\n32\tjavascript\n33\tpython\n34\thibernate,java,spring\n35\t\n36\tc#,wpf,xaml\n37\tjavascript\n38\tphp\n39\tjava\n40\tjava,sockets\n41\tc#\n42\t\n43\teclipse,java\n44\tc#\n45\tphp\n46\tc#\n47\t\n48\tfile\n49\teclipse,java\n50\tjavascript,jquery\n51\t\n52\tc++\n53\tjavascript\n54\tjavascript\n55\t\n56\tpython\n57\tc#\n58\tios,objective-c\n59\thtml,javascript\n60\tjava\n61\tdate,javascript,validation\n62\t\n63\tc#\n64\tdjango\n65\tpython\n66\tstring\n67\tpython\n68\t\n69\tjavascript\n70\tjavascript,jquery\n71\tc++\n72\tpython\n73\t\n74\tpython\n75\tajax,php\n76\t\n77\t\n78\tc#,string\n79\tphp\n80\thtml\n81\tobjective-c\n82\tajax,javascript,jquery\n83\tnumpy,python\n84\tasp.net,c#\n85\tpython\n86\t\n87\tjava\n88\txml\n89\t\n90\tjavascript\n91\t\n92\tpython\n93\tjava,swing\n94\tjava\n95\t\n96\tjava\n97\t\n98\tobjective-c,xml\n99\truby-on-rails\n100\t\n101\t\n102\tdjango,python,ruby,ruby-on-rails\n103\thtml,javascript\n104\tc#\n105\tc#,wpf\n106\tc++,qt,visual-studio\n107\truby-on-rails\n108\t\n109\tphp\n110\tjava,swing\n111\tjavascript\n112\tjava,swing\n113\tasp.net,c#\n114\teclipse,java\n115\tlaravel,php\n116\tc#\n117\tjavascript\n118\t\n119\tajax,php\n120\tphp\n121\truby-on-rails\n122\t\n123\tjavascript\n124\tarrays,php\n125\tjava\n126\tpython\n127\tangularjs,javascript\n128\tpandas,python\n129\tgoogle-maps,javascript,json\n130\tjava\n131\t\n132\thtml,javascript\n133\t\n134\t\n135\t\n136\tpython\n137\tc\n138\t\n139\tjavascript,mongodb,node.js\n140\tarrays,c#\n141\tc#\n142\tjava\n143\t.net,c#,json\n144\tjavascript\n145\tasp.net-mvc,c#\n146\tios,objective-c\n147\tpython\n148\tangularjs,javascript\n149\tjavascript,jquery\n150\tregex\n151\teclipse,javascript\n152\tasp.net-mvc,javascript\n153\thibernate,java\n154\thibernate,java,sql\n155\tjavascript\n156\t\n157\truby\n158\tjavascript,jsp\n159\t\n160\tjavascript,jquery\n161\tjava\n162\thibernate,java,mysql,sql-server\n163\tphp\n164\tlaravel,php\n165\t\n166\tjava\n167\tangularjs,javascript\n168\tc#\n169\t\n170\tpython\n171\tc++\n172\tios,swift\n173\tjavascript\n174\tc#,vb.net,winforms\n175\t\n176\t\n177\tc#\n178\tc#\n179\tc#,multithreading\n180\tjavascript\n181\t.net,c#\n182\tc#\n183\tphp,string\n184\tphp\n185\tjavascript\n186\tjavascript\n187\tjava\n188\tiphone,javascript\n189\tc++\n190\tpython\n191\tpython\n192\tc++\n193\tjavascript,jquery,regex,validation\n194\tjavascript\n195\t\n196\t\n197\tjavascript,jquery\n198\t\n199\tarrays,java\n200\tmysql,php\n201\tc#,wpf\n202\t\n203\tc#\n204\t\n205\tphp\n206\tc++\n207\tc#,datetime\n208\tarrays,c,pointers\n209\tjavascript,php\n210\tc++,pointers\n211\t\n212\t\n213\tphp\n214\tpython,xml\n215\tjava\n216\tphp,xml\n217\t\n218\truby-on-rails\n219\tclass,java,oop\n220\tiphone,objective-c\n221\tlinux,python\n222\tpython\n223\t\n224\tlaravel,php\n225\t\n226\tjavascript,jquery\n227\t\n228\tjava\n229\t\n230\t\n231\tpython\n232\tc#,linq\n233\tc,c++\n234\tregex\n235\tajax,javascript,jquery,php\n236\tjavascript\n237\tunit-testing\n238\tr\n239\tasp.net,asp.net-mvc,c#\n240\tphp\n241\tjavascript,jquery\n242\tasp.net,c#\n243\tphp\n244\t\n245\truby,ruby-on-rails,ruby-on-rails-3\n246\t\n247\truby\n248\tjava,spring\n249\tjava,spring\n250\tjavascript\n251\tjavascript,jquery\n252\tpython\n253\t\n254\truby\n255\tc#\n256\tjavascript,php\n257\t\n258\tdjango\n259\t\n260\t\n261\tc++\n262\tjavascript\n263\tdjango\n264\tc++\n265\tjava\n266\tobjective-c\n267\tcodeigniter,php\n268\tc#\n269\tpandas,r\n270\tpython\n271\thtml\n272\tc#\n273\tjava\n274\teclipse,java\n275\t\n276\thtml,javascript\n277\tasp.net,c#\n278\t\n279\tc\n280 ...
